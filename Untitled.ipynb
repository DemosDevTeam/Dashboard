# %%
import pandas as pd
import json

# %%
users = pd.read_csv('data/csv/users.csv')
users = (users[['age', 'children', 'education', 'gender',
                'income', 'marital', 'occupation', 'race']]).dropna()

videos = pd.read_csv('data/csv/videos.csv', index_col=0, encoding='latin1')
#print(videos)
videos = pd.DataFrame.from_dict(videos.iloc[:, 1:])
# print(videos.shape)
# print(videos.head())
#print(videos.iloc[:, 1:])

for i in videos:
    print(i)
    node = videos[i][0]
    dateIdx = node.find('date')

    dictString = videos[i][0][dateIdx:]
    dictString = "{\'" + dictString
    dictString = dictString.replace('\'', '\"')
    dictString = dictString.replace('0,', '\"0\",')
    dictString = dictString.replace('0}', '\"0\"}')

    # print(dictString)
    # newDict = json.loads(dictString)
    # print(type(newDict))
    # print(newDict)
    
    df = pd.DataFrame.from_dict(newDict).head()
    # print(df.shape)
    
    # print(df.iloc[1,:], '\n\n')    
    
    print(df)
# Out:
# Growth and Development
#                                                             date  \
# Housing                                             2018/8/31:22
# What changes are most relevant to you as a home...  2018/8/31:22
#
#                                                                                           mcquestions  \
# Housing                                                                                           NaN
# What changes are most relevant to you as a home...  {'Home values are rising, which I think is goo...
#
#                                                                         name  \
# Housing                                             Property Values - Owners
# What changes are most relevant to you as a home...  Property Values - Owners
#
#                                                    tags  \
# Housing
# What changes are most relevant to you as a home...  NaN
#
#                                                                                           urlpic  \
# Housing                                             https://img.youtube.com/vi/rG1914fdZRM/0.jpg
# What changes are most relevant to you as a home...  https://img.youtube.com/vi/rG1914fdZRM/0.jpg
#
#                                                                                      urlvideo
# Housing                                             https://www.youtube.com/embed/rG1914fdZRM
# What changes are most relevant to you as a home...  https://www.youtube.com/embed/rG1914fdZRM
# New Development in The Neighborhood
#                                                             date  \
# Housing                                             2018/8/31:22
# What changes are most relevant to you as a home...  2018/8/31:22
#
#                                                                                           mcquestions  \
# Housing                                                                                           NaN
# What changes are most relevant to you as a home...  {'Home values are rising, which I think is goo...
#
#                                                                         name  \
# Housing                                             Property Values - Owners
# What changes are most relevant to you as a home...  Property Values - Owners
#
#                                                    tags  \
# Housing
# What changes are most relevant to you as a home...  NaN
#
#                                                                                           urlpic  \
# Housing                                             https://img.youtube.com/vi/rG1914fdZRM/0.jpg
# What changes are most relevant to you as a home...  https://img.youtube.com/vi/rG1914fdZRM/0.jpg
#
#                                                                                      urlvideo
# Housing                                             https://www.youtube.com/embed/rG1914fdZRM
# What changes are most relevant to you as a home...  https://www.youtube.com/embed/rG1914fdZRM
# Pedestrian Safety
#                                                             date  \
# Housing                                             2018/8/31:22
# What changes are most relevant to you as a home...  2018/8/31:22
#
#                                                                                           mcquestions  \
# Housing                                                                                           NaN
# What changes are most relevant to you as a home...  {'Home values are rising, which I think is goo...
#
#                                                                         name  \
# Housing                                             Property Values - Owners
# What changes are most relevant to you as a home...  Property Values - Owners
#
#                                                    tags  \
# Housing
# What changes are most relevant to you as a home...  NaN
#
#                                                                                           urlpic  \
# Housing                                             https://img.youtube.com/vi/rG1914fdZRM/0.jpg
# What changes are most relevant to you as a home...  https://img.youtube.com/vi/rG1914fdZRM/0.jpg
#
#                                                                                      urlvideo
# Housing                                             https://www.youtube.com/embed/rG1914fdZRM
# What changes are most relevant to you as a home...  https://www.youtube.com/embed/rG1914fdZRM
# Property Values - Owners
#                                                             date  \
# Housing                                             2018/8/31:22
# What changes are most relevant to you as a home...  2018/8/31:22
#
#                                                                                           mcquestions  \
# Housing                                                                                           NaN
# What changes are most relevant to you as a home...  {'Home values are rising, which I think is goo...
#
#                                                                         name  \
# Housing                                             Property Values - Owners
# What changes are most relevant to you as a home...  Property Values - Owners
#
#                                                    tags  \
# Housing
# What changes are most relevant to you as a home...  NaN
#
#                                                                                           urlpic  \
# Housing                                             https://img.youtube.com/vi/rG1914fdZRM/0.jpg
# What changes are most relevant to you as a home...  https://img.youtube.com/vi/rG1914fdZRM/0.jpg
#
#                                                                                      urlvideo
# Housing                                             https://www.youtube.com/embed/rG1914fdZRM
# What changes are most relevant to you as a home...  https://www.youtube.com/embed/rG1914fdZRM
# Property Values - Renters
#                                                             date  \
# Housing                                             2018/8/31:22
# What changes are most relevant to you as a home...  2018/8/31:22
#
#                                                                                           mcquestions  \
# Housing                                                                                           NaN
# What changes are most relevant to you as a home...  {'Home values are rising, which I think is goo...
#
#                                                                         name  \
# Housing                                             Property Values - Owners
# What changes are most relevant to you as a home...  Property Values - Owners
#
#                                                    tags  \
# Housing
# What changes are most relevant to you as a home...  NaN
#
#                                                                                           urlpic  \
# Housing                                             https://img.youtube.com/vi/rG1914fdZRM/0.jpg
# What changes are most relevant to you as a home...  https://img.youtube.com/vi/rG1914fdZRM/0.jpg
#
#                                                                                      urlvideo
# Housing                                             https://www.youtube.com/embed/rG1914fdZRM
# What changes are most relevant to you as a home...  https://www.youtube.com/embed/rG1914fdZRM
# Trees in Glenwood
#                                                             date  \
# Housing                                             2018/8/31:22
# What changes are most relevant to you as a home...  2018/8/31:22
#
#                                                                                           mcquestions  \
# Housing                                                                                           NaN
# What changes are most relevant to you as a home...  {'Home values are rising, which I think is goo...
#
#                                                                         name  \
# Housing                                             Property Values - Owners
# What changes are most relevant to you as a home...  Property Values - Owners
#
#                                                    tags  \
# Housing
# What changes are most relevant to you as a home...  NaN
#
#                                                                                           urlpic  \
# Housing                                             https://img.youtube.com/vi/rG1914fdZRM/0.jpg
# What changes are most relevant to you as a home...  https://img.youtube.com/vi/rG1914fdZRM/0.jpg
#
#                                                                                      urlvideo
# Housing                                             https://www.youtube.com/embed/rG1914fdZRM
# What changes are most relevant to you as a home...  https://www.youtube.com/embed/rG1914fdZRM
# Upkeep of Rental Housing
#                                                             date  \
# Housing                                             2018/8/31:22
# What changes are most relevant to you as a home...  2018/8/31:22
#
#                                                                                           mcquestions  \
# Housing                                                                                           NaN
# What changes are most relevant to you as a home...  {'Home values are rising, which I think is goo...
#
#                                                                         name  \
# Housing                                             Property Values - Owners
# What changes are most relevant to you as a home...  Property Values - Owners
#
#                                                    tags  \
# Housing
# What changes are most relevant to you as a home...  NaN
#
#                                                                                           urlpic  \
# Housing                                             https://img.youtube.com/vi/rG1914fdZRM/0.jpg
# What changes are most relevant to you as a home...  https://img.youtube.com/vi/rG1914fdZRM/0.jpg
#
#                                                                                      urlvideo
# Housing                                             https://www.youtube.com/embed/rG1914fdZRM
# What changes are most relevant to you as a home...  https://www.youtube.com/embed/rG1914fdZRM
# What is Planit GSO
#                                                             date  \
# Housing                                             2018/8/31:22
# What changes are most relevant to you as a home...  2018/8/31:22
#
#                                                                                           mcquestions  \
# Housing                                                                                           NaN
# What changes are most relevant to you as a home...  {'Home values are rising, which I think is goo...
#
#                                                                         name  \
# Housing                                             Property Values - Owners
# What changes are most relevant to you as a home...  Property Values - Owners
#
#                                                    tags  \
# Housing
# What changes are most relevant to you as a home...  NaN
#
#                                                                                           urlpic  \
# Housing                                             https://img.youtube.com/vi/rG1914fdZRM/0.jpg
# What changes are most relevant to you as a home...  https://img.youtube.com/vi/rG1914fdZRM/0.jpg
#
#                                                                                      urlvideo
# Housing                                             https://www.youtube.com/embed/rG1914fdZRM
# What changes are most relevant to you as a home...  https://www.youtube.com/embed/rG1914fdZRM
# What matters to you?
#                                                             date  \
# Housing                                             2018/8/31:22
# What changes are most relevant to you as a home...  2018/8/31:22
#
#                                                                                           mcquestions  \
# Housing                                                                                           NaN
# What changes are most relevant to you as a home...  {'Home values are rising, which I think is goo...
#
#                                                                         name  \
# Housing                                             Property Values - Owners
# What changes are most relevant to you as a home...  Property Values - Owners
#
#                                                    tags  \
# Housing
# What changes are most relevant to you as a home...  NaN
#
#                                                                                           urlpic  \
# Housing                                             https://img.youtube.com/vi/rG1914fdZRM/0.jpg
# What changes are most relevant to you as a home...  https://img.youtube.com/vi/rG1914fdZRM/0.jpg
#
#                                                                                      urlvideo
# Housing                                             https://www.youtube.com/embed/rG1914fdZRM
# What changes are most relevant to you as a home...  https://www.youtube.com/embed/rG1914fdZRM
